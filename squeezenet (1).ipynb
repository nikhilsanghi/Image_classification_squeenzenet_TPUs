# %% [markdown]
# ##Classification of flowers images using model Squeezenet on Cloud TPUs on Tensorflow.**bold text**

# %% [markdown]
# We need to access personal GCS bucket
# gs://nikhil-sanghi-tpu, authenticating this

# %%
from google.colab import auth
auth.authenticate_user()

# %%
import os, sys, math
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from datetime import datetime

print("Tensorflow version " + tf.__version__)

AUTOTUNE = tf.data.AUTOTUNE
# Out:
# Tensorflow version 2.7.0

# %%
import tensorboard

# %%
GCS_PATTERN_JPG = 'gs://flowers-public/*/*.jpg'
GCS_OUTPUT_TFR = 'gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers'  
TARGET_SIZE = [192, 192]
CLASSES = [b'daisy', b'dandelion', b'roses', b'sunflowers', b'tulips'] 
SHARDS=16

# %%
def dataset_to_numpy_util(dataset, N):
  dataset = dataset.batch(N)
  
  # In eager mode, iterate in the Datset directly.
  for images, labels in dataset:
    numpy_images = images.numpy()
    numpy_labels = labels.numpy()
    break;

  return numpy_images, numpy_labels

def title_from_label_and_target(label, correct_label):
  label = np.argmax(label, axis=-1)  # one-hot to class number
  correct_label = np.argmax(correct_label, axis=-1) # one-hot to class number
  correct = (label == correct_label)
  return "{} [{}{}{}]".format(CLASSES[label], str(correct), ', shoud be ' if not correct else '',
                              CLASSES[correct_label] if not correct else ''), correct

def display_one_flower(image, title, subplot, red=False):
    plt.subplot(subplot)
    plt.axis('off')
    plt.imshow(image)
    plt.title(title, fontsize=16, color='red' if red else 'black')
    return subplot+1
  
def display_9_images_from_dataset(dataset):
  subplot=331
  plt.figure(figsize=(13,13))
  images, labels = dataset_to_numpy_util(dataset, 9)
  for i, image in enumerate(images):
    title = CLASSES[np.argmax(labels[i], axis=-1)]
    subplot = display_one_flower(image, title, subplot)
    if i >= 8:
      break;
              
  #plt.tight_layout()
  plt.subplots_adjust(wspace=0.1, hspace=0.1)
  plt.show()
  
def display_9_images_with_predictions(images, predictions, labels):
  subplot=331
  plt.figure(figsize=(13,13))
  for i, image in enumerate(images):
    title, correct = title_from_label_and_target(predictions[i], labels[i])
    subplot = display_one_flower(image, title, subplot, not correct)
    if i >= 8:
      break;
              
  #plt.tight_layout()
  plt.subplots_adjust(wspace=0.1, hspace=0.1)
  plt.show()
  
def display_training_curves(training, validation, title, subplot):
  if subplot%10==1: # set up the subplots on the first call
    plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
    #plt.tight_layout()
  ax = plt.subplot(subplot)
  ax.set_facecolor('#F8F8F8')
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['train', 'valid.'])

def decode_jpeg_and_label(filename):
  bits = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(bits)
  # parse flower name from containing directory
  label = tf.strings.split(tf.expand_dims(filename, axis=-1), sep='/')
  label = label.values[-2]
  return image, label

def resize_and_crop_image(image, label):
  # Resize and crop using "fill" algorithm:
  # always make sure the resulting image
  # is cut out from the source image so that
  # it fills the TARGET_SIZE entirely with no
  # black bars and a preserved aspect ratio.
  w = tf.shape(image)[0]
  h = tf.shape(image)[1]
  tw = TARGET_SIZE[1]
  th = TARGET_SIZE[0]
  resize_crit = (w * th) / (h * tw)
  image = tf.cond(resize_crit < 1,
                  lambda: tf.image.resize(image, [w*tw/w, h*tw/w]), # if true
                  lambda: tf.image.resize(image, [w*th/h, h*th/h])  # if false
                 )
  nw = tf.shape(image)[0]
  nh = tf.shape(image)[1]
  image = tf.image.crop_to_bounding_box(image, (nw - tw) // 2, (nh - th) // 2, tw, th)
  return image, label

def recompress_image(image, label):
  height = tf.shape(image)[0]
  width = tf.shape(image)[1]
  image = tf.cast(image, tf.uint8)
  image = tf.image.encode_jpeg(image, optimize_size=True, chroma_downsampling=False)
  return image, label, height, width

# %%
nb_images = len(tf.io.gfile.glob(GCS_PATTERN_JPG))
shard_size = math.ceil(1.0 * nb_images / SHARDS)
print("Pattern matches {} images which will be rewritten as {} .tfrec files containing {} images each.".format(nb_images, SHARDS, shard_size))

filenames = tf.data.Dataset.list_files(GCS_PATTERN_JPG, seed=35155) # This also shuffles the images
dataset = filenames.map(decode_jpeg_and_label, num_parallel_calls=AUTOTUNE)
# Out:
# Pattern matches 3670 images which will be rewritten as 16 .tfrec files containing 230 images each.

# %%
dataset = dataset.map(resize_and_crop_image, num_parallel_calls=AUTOTUNE)

# %%
dataset = dataset.map(recompress_image, num_parallel_calls=AUTOTUNE)
dataset = dataset.batch(shard_size) # sharding: there will be one "batch" of images per file

# %%
# Three types of data can be stored in TFRecords: bytestrings, integers and floats
# They are always stored as lists, a single data element will be a list of size 1

def _bytestring_feature(list_of_bytestrings):
  return tf.train.Feature(bytes_list=tf.train.BytesList(value=list_of_bytestrings))

def _int_feature(list_of_ints): # int64
  return tf.train.Feature(int64_list=tf.train.Int64List(value=list_of_ints))

def _float_feature(list_of_floats): # float32
  return tf.train.Feature(float_list=tf.train.FloatList(value=list_of_floats))
  

def to_tfrecord(tfrec_filewriter, img_bytes, label, height, width):  
  class_num = np.argmax(np.array(CLASSES)==label) # 'roses' => 2 (order defined in CLASSES)
  one_hot_class = np.eye(len(CLASSES))[class_num]     # [0, 0, 1, 0, 0] for class #2, roses

  feature = {
      "image": _bytestring_feature([img_bytes]), # one image in the list
      "class": _int_feature([class_num]),        # one class in the list
      
      # additional (not very useful) fields to demonstrate TFRecord writing/reading of different types of data
      "label":         _bytestring_feature([label]),          # fixed length (1) list of strings, the text label
      "size":          _int_feature([height, width]),         # fixed length (2) list of ints
      "one_hot_class": _float_feature(one_hot_class.tolist()) # variable length  list of floats, n=len(CLASSES)
  }
  return tf.train.Example(features=tf.train.Features(feature=feature))
  
print("Writing TFRecords")
for shard, (image, label, height, width) in enumerate(dataset):
  # batch size used as shard size here
  shard_size = image.numpy().shape[0]
  # good practice to have the number of records in the filename
  filename = GCS_OUTPUT_TFR + "{:02d}-{}.tfrec".format(shard, shard_size)
  
  with tf.io.TFRecordWriter(filename) as out_file:
    for i in range(shard_size):
      example = to_tfrecord(out_file,
                            image.numpy()[i], # re-compressed image: already a byte string
                            label.numpy()[i],
                            height.numpy()[i],
                            width.numpy()[i])
      out_file.write(example.SerializeToString())
    print("Wrote file {} containing {} records".format(filename, shard_size))
# Out:
# Writing TFRecords
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers00-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers01-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers02-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers03-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers04-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers05-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers06-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers07-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers08-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers09-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers10-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers11-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers12-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers13-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers14-230.tfrec containing 230 records
# Wrote file gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/flowers15-220.tfrec containing 220 records

# %%
def read_tfrecord(example):
    features = {
        "image": tf.io.FixedLenFeature([], tf.string),  # tf.string = bytestring (not text string)
        "class": tf.io.FixedLenFeature([], tf.int64),   # shape [] means scalar
        
        # additional (not very useful) fields to demonstrate TFRecord writing/reading of different types of data
        "label":         tf.io.FixedLenFeature([], tf.string),  # one bytestring
        "size":          tf.io.FixedLenFeature([2], tf.int64),  # two integers
        "one_hot_class": tf.io.VarLenFeature(tf.float32)        # a certain number of floats
    }
    # decode the TFRecord
    example = tf.io.parse_single_example(example, features)
    
    # FixedLenFeature fields are now ready to use: exmple['size']
    # VarLenFeature fields require additional sparse_to_dense decoding
    
    image = tf.io.decode_jpeg(example['image'], channels=3)
    image = tf.reshape(image, [*TARGET_SIZE, 3])
    
    class_num = example['class']
    
    label  = example['label']
    height = example['size'][0]
    width  = example['size'][1]
    one_hot_class = tf.sparse.to_dense(example['one_hot_class'])
    return image, class_num, label, height, width, one_hot_class
    
# read from TFRecords. For optimal performance, read from multiple
# TFRecord files at once and set the option experimental_deterministic = False
# to allow order-altering optimizations.

option_no_order = tf.data.Options()
option_no_order.experimental_deterministic = False

filenames = tf.io.gfile.glob(GCS_OUTPUT_TFR + "*.tfrec")
dataset4 = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE)
dataset4 = dataset4.with_options(option_no_order)
dataset4 = dataset4.map(read_tfrecord, num_parallel_calls=AUTOTUNE)
dataset4 = dataset4.shuffle(300)

# %%
for image, class_num, label, height, width, one_hot_class in dataset4.take(300):
    print("Image shape {}, {}x{} px, class={} ({:>10}, {})".format(image.numpy().shape, width, height, class_num, label.numpy().decode('utf8'), one_hot_class))
# Out:
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=3 (sunflowers, [0. 0. 0. 1. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])
# Image shape (192, 192, 3), 192x192 px, class=2 (     roses, [0. 0. 1. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=0 (     daisy, [1. 0. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=1 ( dandelion, [0. 1. 0. 0. 0.])
# Image shape (192, 192, 3), 192x192 px, class=4 (    tulips, [0. 0. 0. 0. 1.])

# %%
try: 
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect() 
  strategy = tf.distribute.TPUStrategy(tpu)
except ValueError: 
  strategy = tf.distribute.MirroredStrategy() 
print("Number of accelerators: ", strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: grpc://10.14.110.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.14.110.18:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# Number of accelerators:  8

# %%
GCS_PATTERN = 'gs://nikhil-sanghi-tpu/tfrecords-jpeg-192x192-2/*.tfrec'
IMAGE_SIZE = [192, 192]

if tpu:
  BATCH_SIZE = 16*strategy.num_replicas_in_sync  # A TPU has 8 cores so this will be 128
else:
  BATCH_SIZE = 32  # On Colab/GPU, a higher batch size does not help and sometimes does not fit on the GPU (OOM)

# BATCH_SIZE = 32
VALIDATION_SPLIT = 0.19
CLASSES = ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips'] # do not change, maps to the labels in the data (folder names)

# splitting data files between training and validation
filenames = tf.io.gfile.glob(GCS_PATTERN)
split = int(len(filenames) * VALIDATION_SPLIT)
training_filenames = filenames[split:]
validation_filenames = filenames[:split]
print("Pattern matches {} data files. Splitting dataset into {} training files and {} validation files".format(len(filenames), len(training_filenames), len(validation_filenames)))
validation_steps = int(3670 // len(filenames) * len(validation_filenames)) // BATCH_SIZE
steps_per_epoch = int(3670 // len(filenames) * len(training_filenames)) // BATCH_SIZE
print("With a batch size of {}, there will be {} batches per training epoch and {} batch(es) per validation run.".format(BATCH_SIZE, steps_per_epoch, validation_steps))
# Out:
# Pattern matches 16 data files. Splitting dataset into 13 training files and 3 validation files
# With a batch size of 128, there will be 23 batches per training epoch and 5 batch(es) per validation run.

# %%
def read_tfrecord(example):
    features = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "class": tf.io.FixedLenFeature([], tf.int64),  # shape [] means scalar
        "one_hot_class": tf.io.VarLenFeature(tf.float32),
    }
    example = tf.io.parse_single_example(example, features)
    image = tf.io.decode_jpeg(example['image'], channels=3)
    image = tf.cast(image, tf.float32) / 255.0  # convert image to floats in [0, 1] range
    image = tf.reshape(image, [*IMAGE_SIZE, 3]) # explicit size will be needed for TPU
    one_hot_class = tf.sparse.to_dense(example['one_hot_class'])
    one_hot_class = tf.reshape(one_hot_class, [5])
    return image, one_hot_class

def load_dataset(filenames):
  # read from TFRecords. For optimal performance, read from multiple
  # TFRecord files at once and set the option experimental_deterministic = False
  # to allow order-altering optimizations.

  option_no_order = tf.data.Options()
  option_no_order.experimental_deterministic = False

  dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE)
  dataset = dataset.with_options(option_no_order)
  dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTOTUNE)
  return dataset

# %%
def data_augment(image, one_hot_class):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_saturation(image, 0, 2)
    return image, one_hot_class

def get_batched_dataset(filenames, train=False):
  dataset = load_dataset(filenames)
  dataset = dataset.cache() # This dataset fits in RAM
  if train:
    # Best practices for Keras:
    # Training dataset: repeat then batch
    # Evaluation dataset: do not repeat
    dataset = dataset.repeat()
    dataset = dataset.map(data_augment, num_parallel_calls=AUTOTUNE)
    dataset = dataset.shuffle(2000)
  dataset = dataset.batch(BATCH_SIZE)
  dataset = dataset.prefetch(AUTOTUNE) # prefetch next batch while training (autotune prefetch buffer size)
  # should shuffle too but this dataset was well shuffled on disk already
  return dataset
  # source: Dataset performance guide: https://www.tensorflow.org/guide/performance/datasets

# instantiate the datasets
training_dataset = get_batched_dataset(training_filenames, train=True)
validation_dataset = get_batched_dataset(validation_filenames, train=False)

some_flowers, some_labels = dataset_to_numpy_util(load_dataset(validation_filenames), 160)

# %%
with strategy.scope(): # this line is all that is needed to run on TPU (or multi-GPU, ...)

  bnmomemtum=0.9
  def fire(x, squeeze, expand):
    y  = tf.keras.layers.Conv2D(filters=squeeze, kernel_size=1, activation='relu', padding='same')(x)
    y = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y)
    y1 = tf.keras.layers.Conv2D(filters=expand//2, kernel_size=1, activation='relu', padding='same')(y)
    y1 = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y1)
    y3 = tf.keras.layers.Conv2D(filters=expand//2, kernel_size=3, activation='relu', padding='same')(y)
    y3 = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y3)
    return tf.keras.layers.concatenate([y1, y3])

  def fire_module(squeeze, expand):
    return lambda x: fire(x, squeeze, expand)

  x = tf.keras.layers.Input(shape=[*IMAGE_SIZE, 3]) # input is 192x192 pixels RGB

  y = tf.keras.layers.Conv2D(kernel_size=3, filters=32, padding='same', use_bias=True, activation='relu')(x)
  y = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y)
  y = fire_module(24, 48)(y)
  y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
  y = fire_module(48, 96)(y)
  y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
  y = fire_module(64, 128)(y)
  y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
  y = fire_module(48, 96)(y)
  y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
  y = fire_module(24, 48)(y)
  y = tf.keras.layers.GlobalAveragePooling2D()(y)
  y = tf.keras.layers.Dense(5, activation='softmax')(y)

  model = tf.keras.Model(x, y)

  model.compile(
    optimizer='adam',
    loss= 'categorical_crossentropy',
    metrics=['accuracy'],)

  model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 192, 192, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 192, 192, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 192, 192, 24  792         ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 192, 192, 24  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  conv2d_2 (Conv2D)              (None, 192, 192, 24  600         ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 192, 192, 24  5208        ['batch_normalization_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 192, 192, 24  96         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_3 (BatchNo  (None, 192, 192, 24  96         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  concatenate (Concatenate)      (None, 192, 192, 48  0           ['batch_normalization_2[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 96, 96, 48)   0           ['concatenate[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 96, 96, 48)   2352        ['max_pooling2d[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96, 96, 48)  192         ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 96, 96, 48)   2352        ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 96, 96, 48)   20784       ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 96, 96, 48)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 96, 96, 48)  192         ['conv2d_6[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 96, 96, 96)   0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 48, 48, 96)  0           ['concatenate_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 48, 48, 64)   6208        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 48, 48, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 48, 48, 64)   4160        ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 48, 48, 64)   36928       ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 48, 48, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 48, 48, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  concatenate_2 (Concatenate)    (None, 48, 48, 128)  0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 24, 24, 128)  0          ['concatenate_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 24, 24, 48)   6192        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 24, 24, 48)  192         ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 24, 24, 48)   2352        ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 24, 24, 48)   20784       ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 24, 24, 48)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 24, 24, 48)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  concatenate_3 (Concatenate)    (None, 24, 24, 96)   0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 96)  0           ['concatenate_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 12, 12, 24)   2328        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 12, 12, 24)  96          ['conv2d_13[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 24)   600         ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 12, 12, 24)   5208        ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 12, 12, 24)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 12, 12, 24)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  concatenate_4 (Concatenate)    (None, 12, 12, 48)   0           ['batch_normalization_14[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 48)          0           ['concatenate_4[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 5)            245         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 120,613
# Trainable params: 119,301
# Non-trainable params: 1,312
# __________________________________________________________________________________________________

# %%
EPOCHS = 150
start_lr = 0.00001
min_lr = 0.000001
max_lr = 0.00010 * strategy.num_replicas_in_sync
rampup_epochs = 10
sustain_epochs = 0
exp_decay = .8

def lrfn(epoch):
  if epoch < rampup_epochs:
    return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
  elif epoch < rampup_epochs + sustain_epochs:
    return max_lr
  else:
    return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr
    
lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=True)

rang = np.arange(EPOCHS)
y = [lrfn(x) for x in rang]
plt.plot(rang, y)
print('Learning rate per epoch:')
# Out:
# Learning rate per epoch:

# %%
history = model.fit(training_dataset,
                    steps_per_epoch=steps_per_epoch,
                    epochs=EPOCHS,
                    validation_data=validation_dataset,
                    callbacks=[lr_callback]
          )
# Out:
# Epoch 00001: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 1/150
# 23/23 [==============================] - 4s 185ms/step - loss: 0.6420 - accuracy: 0.7799 - val_loss: 0.6336 - val_accuracy: 0.7652 - lr: 1.0000e-05
#
# Epoch 00002: LearningRateScheduler setting learning rate to 8.9e-05.
# Epoch 2/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.6667 - accuracy: 0.7561 - val_loss: 0.6475 - val_accuracy: 0.7406 - lr: 8.9000e-05
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.000168.
# Epoch 3/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.6687 - accuracy: 0.7592 - val_loss: 0.6331 - val_accuracy: 0.7623 - lr: 1.6800e-04
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.000247.
# Epoch 4/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.6526 - accuracy: 0.7660 - val_loss: 0.6458 - val_accuracy: 0.7449 - lr: 2.4700e-04
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.000326.
# Epoch 5/150
# 23/23 [==============================] - 4s 181ms/step - loss: 0.6745 - accuracy: 0.7578 - val_loss: 0.6913 - val_accuracy: 0.7464 - lr: 3.2600e-04
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.000405.
# Epoch 6/150
# 23/23 [==============================] - 4s 178ms/step - loss: 0.6829 - accuracy: 0.7595 - val_loss: 0.6654 - val_accuracy: 0.7493 - lr: 4.0500e-04
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.000484.
# Epoch 7/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.6759 - accuracy: 0.7558 - val_loss: 0.7432 - val_accuracy: 0.7217 - lr: 4.8400e-04
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.000563.
# Epoch 8/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.6607 - accuracy: 0.7554 - val_loss: 0.7381 - val_accuracy: 0.7174 - lr: 5.6300e-04
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.000642.
# Epoch 9/150
# 23/23 [==============================] - 4s 199ms/step - loss: 0.6657 - accuracy: 0.7510 - val_loss: 0.8491 - val_accuracy: 0.7029 - lr: 6.4200e-04
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.000721.
# Epoch 10/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.6792 - accuracy: 0.7507 - val_loss: 0.6437 - val_accuracy: 0.7507 - lr: 7.2100e-04
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0008.
# Epoch 11/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.6745 - accuracy: 0.7544 - val_loss: 0.8337 - val_accuracy: 0.6870 - lr: 8.0000e-04
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0006402000000000001.
# Epoch 12/150
# 23/23 [==============================] - 4s 185ms/step - loss: 0.6552 - accuracy: 0.7575 - val_loss: 0.7361 - val_accuracy: 0.7130 - lr: 6.4020e-04
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0005123600000000001.
# Epoch 13/150
# 23/23 [==============================] - 4s 181ms/step - loss: 0.6130 - accuracy: 0.7700 - val_loss: 0.6495 - val_accuracy: 0.7522 - lr: 5.1236e-04
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00041008800000000013.
# Epoch 14/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.5748 - accuracy: 0.7955 - val_loss: 0.5967 - val_accuracy: 0.7638 - lr: 4.1009e-04
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0003282704000000001.
# Epoch 15/150
# 23/23 [==============================] - 4s 181ms/step - loss: 0.5374 - accuracy: 0.8020 - val_loss: 0.5771 - val_accuracy: 0.7928 - lr: 3.2827e-04
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0002628163200000001.
# Epoch 16/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.5348 - accuracy: 0.8217 - val_loss: 0.5925 - val_accuracy: 0.7696 - lr: 2.6282e-04
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0002104530560000001.
# Epoch 17/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.5268 - accuracy: 0.8101 - val_loss: 0.5870 - val_accuracy: 0.7783 - lr: 2.1045e-04
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00016856244480000006.
# Epoch 18/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4966 - accuracy: 0.8271 - val_loss: 0.5800 - val_accuracy: 0.7754 - lr: 1.6856e-04
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00013504995584000007.
# Epoch 19/150
# 23/23 [==============================] - 4s 187ms/step - loss: 0.5113 - accuracy: 0.8193 - val_loss: 0.5602 - val_accuracy: 0.7812 - lr: 1.3505e-04
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.00010823996467200006.
# Epoch 20/150
# 23/23 [==============================] - 4s 188ms/step - loss: 0.4675 - accuracy: 0.8441 - val_loss: 0.5439 - val_accuracy: 0.8029 - lr: 1.0824e-04
#
# Epoch 00021: LearningRateScheduler setting learning rate to 8.679197173760004e-05.
# Epoch 21/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4823 - accuracy: 0.8427 - val_loss: 0.5434 - val_accuracy: 0.8014 - lr: 8.6792e-05
#
# Epoch 00022: LearningRateScheduler setting learning rate to 6.963357739008005e-05.
# Epoch 22/150
# 23/23 [==============================] - 5s 207ms/step - loss: 0.4760 - accuracy: 0.8285 - val_loss: 0.5357 - val_accuracy: 0.7928 - lr: 6.9634e-05
#
# Epoch 00023: LearningRateScheduler setting learning rate to 5.590686191206403e-05.
# Epoch 23/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4701 - accuracy: 0.8404 - val_loss: 0.5490 - val_accuracy: 0.7942 - lr: 5.5907e-05
#
# Epoch 00024: LearningRateScheduler setting learning rate to 4.4925489529651225e-05.
# Epoch 24/150
# 23/23 [==============================] - 4s 187ms/step - loss: 0.4642 - accuracy: 0.8308 - val_loss: 0.5423 - val_accuracy: 0.7899 - lr: 4.4925e-05
#
# Epoch 00025: LearningRateScheduler setting learning rate to 3.6140391623720984e-05.
# Epoch 25/150
# 23/23 [==============================] - 4s 186ms/step - loss: 0.4427 - accuracy: 0.8543 - val_loss: 0.5354 - val_accuracy: 0.8087 - lr: 3.6140e-05
#
# Epoch 00026: LearningRateScheduler setting learning rate to 2.9112313298976794e-05.
# Epoch 26/150
# 23/23 [==============================] - 4s 188ms/step - loss: 0.4534 - accuracy: 0.8505 - val_loss: 0.5378 - val_accuracy: 0.7957 - lr: 2.9112e-05
#
# Epoch 00027: LearningRateScheduler setting learning rate to 2.3489850639181433e-05.
# Epoch 27/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4569 - accuracy: 0.8373 - val_loss: 0.5302 - val_accuracy: 0.7913 - lr: 2.3490e-05
#
# Epoch 00028: LearningRateScheduler setting learning rate to 1.899188051134515e-05.
# Epoch 28/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4748 - accuracy: 0.8383 - val_loss: 0.5353 - val_accuracy: 0.7971 - lr: 1.8992e-05
#
# Epoch 00029: LearningRateScheduler setting learning rate to 1.539350440907612e-05.
# Epoch 29/150
# 23/23 [==============================] - 4s 181ms/step - loss: 0.4685 - accuracy: 0.8397 - val_loss: 0.5233 - val_accuracy: 0.8058 - lr: 1.5394e-05
#
# Epoch 00030: LearningRateScheduler setting learning rate to 1.2514803527260897e-05.
# Epoch 30/150
# 23/23 [==============================] - 4s 188ms/step - loss: 0.4523 - accuracy: 0.8485 - val_loss: 0.5360 - val_accuracy: 0.7957 - lr: 1.2515e-05
#
# Epoch 00031: LearningRateScheduler setting learning rate to 1.0211842821808719e-05.
# Epoch 31/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4484 - accuracy: 0.8533 - val_loss: 0.5436 - val_accuracy: 0.7942 - lr: 1.0212e-05
#
# Epoch 00032: LearningRateScheduler setting learning rate to 8.369474257446974e-06.
# Epoch 32/150
# 23/23 [==============================] - 4s 190ms/step - loss: 0.4538 - accuracy: 0.8448 - val_loss: 0.5318 - val_accuracy: 0.8101 - lr: 8.3695e-06
#
# Epoch 00033: LearningRateScheduler setting learning rate to 6.8955794059575795e-06.
# Epoch 33/150
# 23/23 [==============================] - 5s 206ms/step - loss: 0.4662 - accuracy: 0.8356 - val_loss: 0.5286 - val_accuracy: 0.8101 - lr: 6.8956e-06
#
# Epoch 00034: LearningRateScheduler setting learning rate to 5.716463524766064e-06.
# Epoch 34/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4476 - accuracy: 0.8458 - val_loss: 0.5316 - val_accuracy: 0.8058 - lr: 5.7165e-06
#
# Epoch 00035: LearningRateScheduler setting learning rate to 4.773170819812852e-06.
# Epoch 35/150
# 23/23 [==============================] - 4s 181ms/step - loss: 0.4585 - accuracy: 0.8353 - val_loss: 0.5263 - val_accuracy: 0.8014 - lr: 4.7732e-06
#
# Epoch 00036: LearningRateScheduler setting learning rate to 4.0185366558502816e-06.
# Epoch 36/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4568 - accuracy: 0.8421 - val_loss: 0.5358 - val_accuracy: 0.7986 - lr: 4.0185e-06
#
# Epoch 00037: LearningRateScheduler setting learning rate to 3.414829324680225e-06.
# Epoch 37/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4466 - accuracy: 0.8356 - val_loss: 0.5271 - val_accuracy: 0.8116 - lr: 3.4148e-06
#
# Epoch 00038: LearningRateScheduler setting learning rate to 2.9318634597441806e-06.
# Epoch 38/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4608 - accuracy: 0.8438 - val_loss: 0.5377 - val_accuracy: 0.7942 - lr: 2.9319e-06
#
# Epoch 00039: LearningRateScheduler setting learning rate to 2.545490767795344e-06.
# Epoch 39/150
# 23/23 [==============================] - 4s 185ms/step - loss: 0.4559 - accuracy: 0.8434 - val_loss: 0.5356 - val_accuracy: 0.7942 - lr: 2.5455e-06
#
# Epoch 00040: LearningRateScheduler setting learning rate to 2.2363926142362756e-06.
# Epoch 40/150
# 23/23 [==============================] - 4s 185ms/step - loss: 0.4370 - accuracy: 0.8563 - val_loss: 0.5392 - val_accuracy: 0.7942 - lr: 2.2364e-06
#
# Epoch 00041: LearningRateScheduler setting learning rate to 1.9891140913890208e-06.
# Epoch 41/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4544 - accuracy: 0.8512 - val_loss: 0.5308 - val_accuracy: 0.8000 - lr: 1.9891e-06
#
# Epoch 00042: LearningRateScheduler setting learning rate to 1.7912912731112164e-06.
# Epoch 42/150
# 23/23 [==============================] - 4s 185ms/step - loss: 0.4593 - accuracy: 0.8404 - val_loss: 0.5311 - val_accuracy: 0.7986 - lr: 1.7913e-06
#
# Epoch 00043: LearningRateScheduler setting learning rate to 1.633033018488973e-06.
# Epoch 43/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4468 - accuracy: 0.8421 - val_loss: 0.5366 - val_accuracy: 0.8000 - lr: 1.6330e-06
#
# Epoch 00044: LearningRateScheduler setting learning rate to 1.5064264147911785e-06.
# Epoch 44/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4446 - accuracy: 0.8465 - val_loss: 0.5417 - val_accuracy: 0.8087 - lr: 1.5064e-06
#
# Epoch 00045: LearningRateScheduler setting learning rate to 1.4051411318329429e-06.
# Epoch 45/150
# 23/23 [==============================] - 5s 204ms/step - loss: 0.4424 - accuracy: 0.8594 - val_loss: 0.5334 - val_accuracy: 0.7942 - lr: 1.4051e-06
#
# Epoch 00046: LearningRateScheduler setting learning rate to 1.3241129054663542e-06.
# Epoch 46/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4401 - accuracy: 0.8495 - val_loss: 0.5394 - val_accuracy: 0.8072 - lr: 1.3241e-06
#
# Epoch 00047: LearningRateScheduler setting learning rate to 1.2592903243730833e-06.
# Epoch 47/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4481 - accuracy: 0.8376 - val_loss: 0.5371 - val_accuracy: 0.7928 - lr: 1.2593e-06
#
# Epoch 00048: LearningRateScheduler setting learning rate to 1.2074322594984667e-06.
# Epoch 48/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4709 - accuracy: 0.8373 - val_loss: 0.5320 - val_accuracy: 0.7986 - lr: 1.2074e-06
#
# Epoch 00049: LearningRateScheduler setting learning rate to 1.1659458075987735e-06.
# Epoch 49/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4319 - accuracy: 0.8475 - val_loss: 0.5326 - val_accuracy: 0.7971 - lr: 1.1659e-06
#
# Epoch 00050: LearningRateScheduler setting learning rate to 1.1327566460790187e-06.
# Epoch 50/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4554 - accuracy: 0.8431 - val_loss: 0.5312 - val_accuracy: 0.8029 - lr: 1.1328e-06
#
# Epoch 00051: LearningRateScheduler setting learning rate to 1.106205316863215e-06.
# Epoch 51/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4503 - accuracy: 0.8499 - val_loss: 0.5314 - val_accuracy: 0.7971 - lr: 1.1062e-06
#
# Epoch 00052: LearningRateScheduler setting learning rate to 1.084964253490572e-06.
# Epoch 52/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4563 - accuracy: 0.8417 - val_loss: 0.5256 - val_accuracy: 0.8072 - lr: 1.0850e-06
#
# Epoch 00053: LearningRateScheduler setting learning rate to 1.0679714027924576e-06.
# Epoch 53/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4550 - accuracy: 0.8441 - val_loss: 0.5411 - val_accuracy: 0.7957 - lr: 1.0680e-06
#
# Epoch 00054: LearningRateScheduler setting learning rate to 1.054377122233966e-06.
# Epoch 54/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4516 - accuracy: 0.8407 - val_loss: 0.5359 - val_accuracy: 0.7899 - lr: 1.0544e-06
#
# Epoch 00055: LearningRateScheduler setting learning rate to 1.0435016977871729e-06.
# Epoch 55/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4594 - accuracy: 0.8417 - val_loss: 0.5358 - val_accuracy: 0.7913 - lr: 1.0435e-06
#
# Epoch 00056: LearningRateScheduler setting learning rate to 1.0348013582297383e-06.
# Epoch 56/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4469 - accuracy: 0.8465 - val_loss: 0.5319 - val_accuracy: 0.8087 - lr: 1.0348e-06
#
# Epoch 00057: LearningRateScheduler setting learning rate to 1.0278410865837907e-06.
# Epoch 57/150
# 23/23 [==============================] - 4s 199ms/step - loss: 0.4267 - accuracy: 0.8584 - val_loss: 0.5317 - val_accuracy: 0.7957 - lr: 1.0278e-06
#
# Epoch 00058: LearningRateScheduler setting learning rate to 1.0222728692670325e-06.
# Epoch 58/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4529 - accuracy: 0.8458 - val_loss: 0.5412 - val_accuracy: 0.7899 - lr: 1.0223e-06
#
# Epoch 00059: LearningRateScheduler setting learning rate to 1.0178182954136259e-06.
# Epoch 59/150
# 23/23 [==============================] - 4s 187ms/step - loss: 0.4485 - accuracy: 0.8376 - val_loss: 0.5330 - val_accuracy: 0.7942 - lr: 1.0178e-06
#
# Epoch 00060: LearningRateScheduler setting learning rate to 1.0142546363309008e-06.
# Epoch 60/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4388 - accuracy: 0.8522 - val_loss: 0.5301 - val_accuracy: 0.8014 - lr: 1.0143e-06
#
# Epoch 00061: LearningRateScheduler setting learning rate to 1.0114037090647207e-06.
# Epoch 61/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4462 - accuracy: 0.8471 - val_loss: 0.5347 - val_accuracy: 0.8072 - lr: 1.0114e-06
#
# Epoch 00062: LearningRateScheduler setting learning rate to 1.0091229672517765e-06.
# Epoch 62/150
# 23/23 [==============================] - 4s 186ms/step - loss: 0.4527 - accuracy: 0.8424 - val_loss: 0.5260 - val_accuracy: 0.8058 - lr: 1.0091e-06
#
# Epoch 00063: LearningRateScheduler setting learning rate to 1.007298373801421e-06.
# Epoch 63/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4546 - accuracy: 0.8475 - val_loss: 0.5308 - val_accuracy: 0.8058 - lr: 1.0073e-06
#
# Epoch 00064: LearningRateScheduler setting learning rate to 1.0058386990411368e-06.
# Epoch 64/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4247 - accuracy: 0.8546 - val_loss: 0.5292 - val_accuracy: 0.8087 - lr: 1.0058e-06
#
# Epoch 00065: LearningRateScheduler setting learning rate to 1.0046709592329096e-06.
# Epoch 65/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4695 - accuracy: 0.8366 - val_loss: 0.5280 - val_accuracy: 0.8000 - lr: 1.0047e-06
#
# Epoch 00066: LearningRateScheduler setting learning rate to 1.0037367673863276e-06.
# Epoch 66/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4403 - accuracy: 0.8444 - val_loss: 0.5367 - val_accuracy: 0.8043 - lr: 1.0037e-06
#
# Epoch 00067: LearningRateScheduler setting learning rate to 1.002989413909062e-06.
# Epoch 67/150
# 23/23 [==============================] - 4s 186ms/step - loss: 0.4494 - accuracy: 0.8414 - val_loss: 0.5311 - val_accuracy: 0.7986 - lr: 1.0030e-06
#
# Epoch 00068: LearningRateScheduler setting learning rate to 1.0023915311272496e-06.
# Epoch 68/150
# 23/23 [==============================] - 4s 191ms/step - loss: 0.4544 - accuracy: 0.8441 - val_loss: 0.5355 - val_accuracy: 0.7928 - lr: 1.0024e-06
#
# Epoch 00069: LearningRateScheduler setting learning rate to 1.0019132249017998e-06.
# Epoch 69/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4470 - accuracy: 0.8485 - val_loss: 0.5257 - val_accuracy: 0.7870 - lr: 1.0019e-06
#
# Epoch 00070: LearningRateScheduler setting learning rate to 1.0015305799214398e-06.
# Epoch 70/150
# 23/23 [==============================] - 5s 204ms/step - loss: 0.4520 - accuracy: 0.8482 - val_loss: 0.5264 - val_accuracy: 0.7971 - lr: 1.0015e-06
#
# Epoch 00071: LearningRateScheduler setting learning rate to 1.0012244639371517e-06.
# Epoch 71/150
# 23/23 [==============================] - 4s 195ms/step - loss: 0.4403 - accuracy: 0.8522 - val_loss: 0.5306 - val_accuracy: 0.7971 - lr: 1.0012e-06
#
# Epoch 00072: LearningRateScheduler setting learning rate to 1.0009795711497215e-06.
# Epoch 72/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4448 - accuracy: 0.8492 - val_loss: 0.5302 - val_accuracy: 0.8014 - lr: 1.0010e-06
#
# Epoch 00073: LearningRateScheduler setting learning rate to 1.0007836569197772e-06.
# Epoch 73/150
# 23/23 [==============================] - 4s 185ms/step - loss: 0.4431 - accuracy: 0.8427 - val_loss: 0.5331 - val_accuracy: 0.8014 - lr: 1.0008e-06
#
# Epoch 00074: LearningRateScheduler setting learning rate to 1.0006269255358218e-06.
# Epoch 74/150
# 23/23 [==============================] - 4s 190ms/step - loss: 0.4488 - accuracy: 0.8478 - val_loss: 0.5353 - val_accuracy: 0.7957 - lr: 1.0006e-06
#
# Epoch 00075: LearningRateScheduler setting learning rate to 1.0005015404286574e-06.
# Epoch 75/150
# 23/23 [==============================] - 4s 191ms/step - loss: 0.4387 - accuracy: 0.8563 - val_loss: 0.5233 - val_accuracy: 0.8072 - lr: 1.0005e-06
#
# Epoch 00076: LearningRateScheduler setting learning rate to 1.000401232342926e-06.
# Epoch 76/150
# 23/23 [==============================] - 4s 176ms/step - loss: 0.4640 - accuracy: 0.8291 - val_loss: 0.5384 - val_accuracy: 0.7986 - lr: 1.0004e-06
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1.0003209858743406e-06.
# Epoch 77/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4300 - accuracy: 0.8550 - val_loss: 0.5372 - val_accuracy: 0.8000 - lr: 1.0003e-06
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1.0002567886994725e-06.
# Epoch 78/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4534 - accuracy: 0.8465 - val_loss: 0.5377 - val_accuracy: 0.7986 - lr: 1.0003e-06
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1.000205430959578e-06.
# Epoch 79/150
# 23/23 [==============================] - 4s 181ms/step - loss: 0.4397 - accuracy: 0.8485 - val_loss: 0.5356 - val_accuracy: 0.7957 - lr: 1.0002e-06
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1.0001643447676624e-06.
# Epoch 80/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4444 - accuracy: 0.8438 - val_loss: 0.5305 - val_accuracy: 0.8000 - lr: 1.0002e-06
#
# Epoch 00081: LearningRateScheduler setting learning rate to 1.0001314758141298e-06.
# Epoch 81/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4228 - accuracy: 0.8628 - val_loss: 0.5348 - val_accuracy: 0.8000 - lr: 1.0001e-06
#
# Epoch 00082: LearningRateScheduler setting learning rate to 1.0001051806513039e-06.
# Epoch 82/150
# 23/23 [==============================] - 5s 201ms/step - loss: 0.4722 - accuracy: 0.8373 - val_loss: 0.5345 - val_accuracy: 0.7928 - lr: 1.0001e-06
#
# Epoch 00083: LearningRateScheduler setting learning rate to 1.000084144521043e-06.
# Epoch 83/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4391 - accuracy: 0.8502 - val_loss: 0.5390 - val_accuracy: 0.8043 - lr: 1.0001e-06
#
# Epoch 00084: LearningRateScheduler setting learning rate to 1.0000673156168345e-06.
# Epoch 84/150
# 23/23 [==============================] - 4s 177ms/step - loss: 0.4417 - accuracy: 0.8451 - val_loss: 0.5365 - val_accuracy: 0.7957 - lr: 1.0001e-06
#
# Epoch 00085: LearningRateScheduler setting learning rate to 1.0000538524934677e-06.
# Epoch 85/150
# 23/23 [==============================] - 4s 181ms/step - loss: 0.4615 - accuracy: 0.8441 - val_loss: 0.5308 - val_accuracy: 0.7971 - lr: 1.0001e-06
#
# Epoch 00086: LearningRateScheduler setting learning rate to 1.000043081994774e-06.
# Epoch 86/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4420 - accuracy: 0.8482 - val_loss: 0.5369 - val_accuracy: 0.7942 - lr: 1.0000e-06
#
# Epoch 00087: LearningRateScheduler setting learning rate to 1.0000344655958192e-06.
# Epoch 87/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4513 - accuracy: 0.8495 - val_loss: 0.5311 - val_accuracy: 0.8087 - lr: 1.0000e-06
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1.0000275724766553e-06.
# Epoch 88/150
# 23/23 [==============================] - 4s 181ms/step - loss: 0.4493 - accuracy: 0.8451 - val_loss: 0.5240 - val_accuracy: 0.8000 - lr: 1.0000e-06
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1.0000220579813243e-06.
# Epoch 89/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4454 - accuracy: 0.8492 - val_loss: 0.5325 - val_accuracy: 0.8058 - lr: 1.0000e-06
#
# Epoch 00090: LearningRateScheduler setting learning rate to 1.0000176463850595e-06.
# Epoch 90/150
# 23/23 [==============================] - 4s 177ms/step - loss: 0.4440 - accuracy: 0.8471 - val_loss: 0.5360 - val_accuracy: 0.7986 - lr: 1.0000e-06
#
# Epoch 00091: LearningRateScheduler setting learning rate to 1.0000141171080475e-06.
# Epoch 91/150
# 23/23 [==============================] - 4s 174ms/step - loss: 0.4611 - accuracy: 0.8410 - val_loss: 0.5267 - val_accuracy: 0.7971 - lr: 1.0000e-06
#
# Epoch 00092: LearningRateScheduler setting learning rate to 1.000011293686438e-06.
# Epoch 92/150
# 23/23 [==============================] - 4s 175ms/step - loss: 0.4614 - accuracy: 0.8448 - val_loss: 0.5327 - val_accuracy: 0.7928 - lr: 1.0000e-06
#
# Epoch 00093: LearningRateScheduler setting learning rate to 1.0000090349491505e-06.
# Epoch 93/150
# 23/23 [==============================] - 4s 178ms/step - loss: 0.4279 - accuracy: 0.8560 - val_loss: 0.5256 - val_accuracy: 0.8014 - lr: 1.0000e-06
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1.0000072279593203e-06.
# Epoch 94/150
# 23/23 [==============================] - 4s 200ms/step - loss: 0.4654 - accuracy: 0.8471 - val_loss: 0.5268 - val_accuracy: 0.8014 - lr: 1.0000e-06
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1.0000057823674562e-06.
# Epoch 95/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4282 - accuracy: 0.8529 - val_loss: 0.5322 - val_accuracy: 0.7942 - lr: 1.0000e-06
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1.000004625893965e-06.
# Epoch 96/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4415 - accuracy: 0.8577 - val_loss: 0.5330 - val_accuracy: 0.8029 - lr: 1.0000e-06
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1.000003700715172e-06.
# Epoch 97/150
# 23/23 [==============================] - 4s 185ms/step - loss: 0.4537 - accuracy: 0.8370 - val_loss: 0.5337 - val_accuracy: 0.8058 - lr: 1.0000e-06
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1.0000029605721376e-06.
# Epoch 98/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4432 - accuracy: 0.8516 - val_loss: 0.5287 - val_accuracy: 0.8072 - lr: 1.0000e-06
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1.00000236845771e-06.
# Epoch 99/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4538 - accuracy: 0.8471 - val_loss: 0.5315 - val_accuracy: 0.8072 - lr: 1.0000e-06
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1.000001894766168e-06.
# Epoch 100/150
# 23/23 [==============================] - 4s 177ms/step - loss: 0.4357 - accuracy: 0.8468 - val_loss: 0.5353 - val_accuracy: 0.7957 - lr: 1.0000e-06
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1.0000015158129344e-06.
# Epoch 101/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4384 - accuracy: 0.8495 - val_loss: 0.5251 - val_accuracy: 0.8072 - lr: 1.0000e-06
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1.0000012126503476e-06.
# Epoch 102/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4592 - accuracy: 0.8458 - val_loss: 0.5330 - val_accuracy: 0.7971 - lr: 1.0000e-06
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1.000000970120278e-06.
# Epoch 103/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4382 - accuracy: 0.8502 - val_loss: 0.5295 - val_accuracy: 0.8058 - lr: 1.0000e-06
#
# Epoch 00104: LearningRateScheduler setting learning rate to 1.0000007760962223e-06.
# Epoch 104/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4550 - accuracy: 0.8485 - val_loss: 0.5352 - val_accuracy: 0.8029 - lr: 1.0000e-06
#
# Epoch 00105: LearningRateScheduler setting learning rate to 1.000000620876978e-06.
# Epoch 105/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4615 - accuracy: 0.8468 - val_loss: 0.5370 - val_accuracy: 0.7957 - lr: 1.0000e-06
#
# Epoch 00106: LearningRateScheduler setting learning rate to 1.0000004967015824e-06.
# Epoch 106/150
# 23/23 [==============================] - 5s 200ms/step - loss: 0.4473 - accuracy: 0.8431 - val_loss: 0.5233 - val_accuracy: 0.8000 - lr: 1.0000e-06
#
# Epoch 00107: LearningRateScheduler setting learning rate to 1.000000397361266e-06.
# Epoch 107/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4521 - accuracy: 0.8458 - val_loss: 0.5313 - val_accuracy: 0.7986 - lr: 1.0000e-06
#
# Epoch 00108: LearningRateScheduler setting learning rate to 1.0000003178890127e-06.
# Epoch 108/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4707 - accuracy: 0.8373 - val_loss: 0.5290 - val_accuracy: 0.8029 - lr: 1.0000e-06
#
# Epoch 00109: LearningRateScheduler setting learning rate to 1.00000025431121e-06.
# Epoch 109/150
# 23/23 [==============================] - 4s 176ms/step - loss: 0.4422 - accuracy: 0.8546 - val_loss: 0.5273 - val_accuracy: 0.7986 - lr: 1.0000e-06
#
# Epoch 00110: LearningRateScheduler setting learning rate to 1.000000203448968e-06.
# Epoch 110/150
# 23/23 [==============================] - 4s 177ms/step - loss: 0.4511 - accuracy: 0.8471 - val_loss: 0.5254 - val_accuracy: 0.8101 - lr: 1.0000e-06
#
# Epoch 00111: LearningRateScheduler setting learning rate to 1.0000001627591744e-06.
# Epoch 111/150
# 23/23 [==============================] - 4s 175ms/step - loss: 0.4251 - accuracy: 0.8601 - val_loss: 0.5301 - val_accuracy: 0.8058 - lr: 1.0000e-06
#
# Epoch 00112: LearningRateScheduler setting learning rate to 1.0000001302073395e-06.
# Epoch 112/150
# 23/23 [==============================] - 4s 178ms/step - loss: 0.4373 - accuracy: 0.8607 - val_loss: 0.5269 - val_accuracy: 0.8101 - lr: 1.0000e-06
#
# Epoch 00113: LearningRateScheduler setting learning rate to 1.0000001041658716e-06.
# Epoch 113/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4477 - accuracy: 0.8468 - val_loss: 0.5279 - val_accuracy: 0.8072 - lr: 1.0000e-06
#
# Epoch 00114: LearningRateScheduler setting learning rate to 1.0000000833326973e-06.
# Epoch 114/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4507 - accuracy: 0.8526 - val_loss: 0.5250 - val_accuracy: 0.7957 - lr: 1.0000e-06
#
# Epoch 00115: LearningRateScheduler setting learning rate to 1.000000066666158e-06.
# Epoch 115/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4326 - accuracy: 0.8553 - val_loss: 0.5259 - val_accuracy: 0.8014 - lr: 1.0000e-06
#
# Epoch 00116: LearningRateScheduler setting learning rate to 1.0000000533329263e-06.
# Epoch 116/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4473 - accuracy: 0.8427 - val_loss: 0.5312 - val_accuracy: 0.8043 - lr: 1.0000e-06
#
# Epoch 00117: LearningRateScheduler setting learning rate to 1.000000042666341e-06.
# Epoch 117/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4406 - accuracy: 0.8492 - val_loss: 0.5295 - val_accuracy: 0.8000 - lr: 1.0000e-06
#
# Epoch 00118: LearningRateScheduler setting learning rate to 1.0000000341330728e-06.
# Epoch 118/150
# 23/23 [==============================] - 4s 199ms/step - loss: 0.4374 - accuracy: 0.8560 - val_loss: 0.5315 - val_accuracy: 0.8000 - lr: 1.0000e-06
#
# Epoch 00119: LearningRateScheduler setting learning rate to 1.0000000273064582e-06.
# Epoch 119/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4594 - accuracy: 0.8390 - val_loss: 0.5308 - val_accuracy: 0.8014 - lr: 1.0000e-06
#
# Epoch 00120: LearningRateScheduler setting learning rate to 1.0000000218451666e-06.
# Epoch 120/150
# 23/23 [==============================] - 4s 176ms/step - loss: 0.4414 - accuracy: 0.8482 - val_loss: 0.5304 - val_accuracy: 0.8043 - lr: 1.0000e-06
#
# Epoch 00121: LearningRateScheduler setting learning rate to 1.0000000174761332e-06.
# Epoch 121/150
# 23/23 [==============================] - 4s 178ms/step - loss: 0.4416 - accuracy: 0.8543 - val_loss: 0.5313 - val_accuracy: 0.8043 - lr: 1.0000e-06
#
# Epoch 00122: LearningRateScheduler setting learning rate to 1.0000000139809066e-06.
# Epoch 122/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4586 - accuracy: 0.8431 - val_loss: 0.5199 - val_accuracy: 0.8072 - lr: 1.0000e-06
#
# Epoch 00123: LearningRateScheduler setting learning rate to 1.0000000111847253e-06.
# Epoch 123/150
# 23/23 [==============================] - 4s 184ms/step - loss: 0.4404 - accuracy: 0.8431 - val_loss: 0.5328 - val_accuracy: 0.8043 - lr: 1.0000e-06
#
# Epoch 00124: LearningRateScheduler setting learning rate to 1.0000000089477803e-06.
# Epoch 124/150
# 23/23 [==============================] - 4s 186ms/step - loss: 0.4681 - accuracy: 0.8410 - val_loss: 0.5259 - val_accuracy: 0.8014 - lr: 1.0000e-06
#
# Epoch 00125: LearningRateScheduler setting learning rate to 1.0000000071582241e-06.
# Epoch 125/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4276 - accuracy: 0.8563 - val_loss: 0.5386 - val_accuracy: 0.7884 - lr: 1.0000e-06
#
# Epoch 00126: LearningRateScheduler setting learning rate to 1.0000000057265792e-06.
# Epoch 126/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4334 - accuracy: 0.8604 - val_loss: 0.5292 - val_accuracy: 0.7971 - lr: 1.0000e-06
#
# Epoch 00127: LearningRateScheduler setting learning rate to 1.0000000045812634e-06.
# Epoch 127/150
# 23/23 [==============================] - 4s 176ms/step - loss: 0.4306 - accuracy: 0.8560 - val_loss: 0.5355 - val_accuracy: 0.7928 - lr: 1.0000e-06
#
# Epoch 00128: LearningRateScheduler setting learning rate to 1.0000000036650107e-06.
# Epoch 128/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4552 - accuracy: 0.8421 - val_loss: 0.5343 - val_accuracy: 0.8014 - lr: 1.0000e-06
#
# Epoch 00129: LearningRateScheduler setting learning rate to 1.0000000029320085e-06.
# Epoch 129/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4338 - accuracy: 0.8584 - val_loss: 0.5218 - val_accuracy: 0.7986 - lr: 1.0000e-06
#
# Epoch 00130: LearningRateScheduler setting learning rate to 1.0000000023456068e-06.
# Epoch 130/150
# 23/23 [==============================] - 5s 205ms/step - loss: 0.4256 - accuracy: 0.8573 - val_loss: 0.5280 - val_accuracy: 0.8029 - lr: 1.0000e-06
#
# Epoch 00131: LearningRateScheduler setting learning rate to 1.0000000018764854e-06.
# Epoch 131/150
# 23/23 [==============================] - 4s 185ms/step - loss: 0.4418 - accuracy: 0.8495 - val_loss: 0.5351 - val_accuracy: 0.7971 - lr: 1.0000e-06
#
# Epoch 00132: LearningRateScheduler setting learning rate to 1.0000000015011884e-06.
# Epoch 132/150
# 23/23 [==============================] - 4s 187ms/step - loss: 0.4606 - accuracy: 0.8427 - val_loss: 0.5351 - val_accuracy: 0.7899 - lr: 1.0000e-06
#
# Epoch 00133: LearningRateScheduler setting learning rate to 1.0000000012009506e-06.
# Epoch 133/150
# 23/23 [==============================] - 4s 191ms/step - loss: 0.4252 - accuracy: 0.8529 - val_loss: 0.5274 - val_accuracy: 0.8014 - lr: 1.0000e-06
#
# Epoch 00134: LearningRateScheduler setting learning rate to 1.0000000009607606e-06.
# Epoch 134/150
# 23/23 [==============================] - 4s 176ms/step - loss: 0.4489 - accuracy: 0.8421 - val_loss: 0.5367 - val_accuracy: 0.7942 - lr: 1.0000e-06
#
# Epoch 00135: LearningRateScheduler setting learning rate to 1.0000000007686085e-06.
# Epoch 135/150
# 23/23 [==============================] - 4s 178ms/step - loss: 0.4554 - accuracy: 0.8458 - val_loss: 0.5323 - val_accuracy: 0.7942 - lr: 1.0000e-06
#
# Epoch 00136: LearningRateScheduler setting learning rate to 1.0000000006148868e-06.
# Epoch 136/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4472 - accuracy: 0.8475 - val_loss: 0.5354 - val_accuracy: 0.8029 - lr: 1.0000e-06
#
# Epoch 00137: LearningRateScheduler setting learning rate to 1.0000000004919095e-06.
# Epoch 137/150
# 23/23 [==============================] - 4s 178ms/step - loss: 0.4497 - accuracy: 0.8407 - val_loss: 0.5184 - val_accuracy: 0.8101 - lr: 1.0000e-06
#
# Epoch 00138: LearningRateScheduler setting learning rate to 1.0000000003935274e-06.
# Epoch 138/150
# 23/23 [==============================] - 4s 178ms/step - loss: 0.4556 - accuracy: 0.8482 - val_loss: 0.5330 - val_accuracy: 0.8043 - lr: 1.0000e-06
#
# Epoch 00139: LearningRateScheduler setting learning rate to 1.000000000314822e-06.
# Epoch 139/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4420 - accuracy: 0.8502 - val_loss: 0.5355 - val_accuracy: 0.7986 - lr: 1.0000e-06
#
# Epoch 00140: LearningRateScheduler setting learning rate to 1.0000000002518576e-06.
# Epoch 140/150
# 23/23 [==============================] - 4s 181ms/step - loss: 0.4425 - accuracy: 0.8536 - val_loss: 0.5317 - val_accuracy: 0.7928 - lr: 1.0000e-06
#
# Epoch 00141: LearningRateScheduler setting learning rate to 1.000000000201486e-06.
# Epoch 141/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4602 - accuracy: 0.8421 - val_loss: 0.5297 - val_accuracy: 0.7957 - lr: 1.0000e-06
#
# Epoch 00142: LearningRateScheduler setting learning rate to 1.0000000001611888e-06.
# Epoch 142/150
# 23/23 [==============================] - 4s 199ms/step - loss: 0.4490 - accuracy: 0.8495 - val_loss: 0.5322 - val_accuracy: 0.7928 - lr: 1.0000e-06
#
# Epoch 00143: LearningRateScheduler setting learning rate to 1.000000000128951e-06.
# Epoch 143/150
# 23/23 [==============================] - 4s 183ms/step - loss: 0.4571 - accuracy: 0.8414 - val_loss: 0.5303 - val_accuracy: 0.7971 - lr: 1.0000e-06
#
# Epoch 00144: LearningRateScheduler setting learning rate to 1.0000000001031607e-06.
# Epoch 144/150
# 23/23 [==============================] - 4s 187ms/step - loss: 0.4499 - accuracy: 0.8529 - val_loss: 0.5274 - val_accuracy: 0.8029 - lr: 1.0000e-06
#
# Epoch 00145: LearningRateScheduler setting learning rate to 1.0000000000825287e-06.
# Epoch 145/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4313 - accuracy: 0.8580 - val_loss: 0.5286 - val_accuracy: 0.8000 - lr: 1.0000e-06
#
# Epoch 00146: LearningRateScheduler setting learning rate to 1.000000000066023e-06.
# Epoch 146/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4581 - accuracy: 0.8383 - val_loss: 0.5300 - val_accuracy: 0.7942 - lr: 1.0000e-06
#
# Epoch 00147: LearningRateScheduler setting learning rate to 1.0000000000528184e-06.
# Epoch 147/150
# 23/23 [==============================] - 4s 178ms/step - loss: 0.4554 - accuracy: 0.8441 - val_loss: 0.5315 - val_accuracy: 0.8014 - lr: 1.0000e-06
#
# Epoch 00148: LearningRateScheduler setting learning rate to 1.0000000000422546e-06.
# Epoch 148/150
# 23/23 [==============================] - 4s 182ms/step - loss: 0.4483 - accuracy: 0.8444 - val_loss: 0.5286 - val_accuracy: 0.8029 - lr: 1.0000e-06
#
# Epoch 00149: LearningRateScheduler setting learning rate to 1.0000000000338038e-06.
# Epoch 149/150
# 23/23 [==============================] - 4s 180ms/step - loss: 0.4495 - accuracy: 0.8441 - val_loss: 0.5291 - val_accuracy: 0.8043 - lr: 1.0000e-06
#
# Epoch 00150: LearningRateScheduler setting learning rate to 1.000000000027043e-06.
# Epoch 150/150
# 23/23 [==============================] - 4s 179ms/step - loss: 0.4375 - accuracy: 0.8519 - val_loss: 0.5323 - val_accuracy: 0.8058 - lr: 1.0000e-06

# %%
final_accuracy = history.history["val_accuracy"][-5:]
print("FINAL ACCURACY MEAN-5: ", np.mean(final_accuracy))
# Out:
# FINAL ACCURACY MEAN-5:  0.8017391562461853

# %%
print(history.history.keys())
display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 211)
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
permutation = np.random.permutation(160)
some_flowers, some_labels = (some_flowers[permutation], some_labels[permutation])

predictions = model.predict(some_flowers, batch_size=16)
evaluations = model.evaluate(some_flowers, some_labels, batch_size=16)
  
print(np.array(CLASSES)[np.argmax(predictions, axis=-1)].tolist())
print('[val_loss, val_acc]', evaluations)
# Out:
# 10/10 [==============================] - 1s 21ms/step - loss: 0.5346 - accuracy: 0.8125
# ['tulips', 'dandelion', 'roses', 'dandelion', 'tulips', 'sunflowers', 'dandelion', 'sunflowers', 'roses', 'tulips', 'roses', 'daisy', 'dandelion', 'tulips', 'sunflowers', 'dandelion', 'dandelion', 'dandelion', 'sunflowers', 'sunflowers', 'sunflowers', 'dandelion', 'dandelion', 'daisy', 'dandelion', 'dandelion', 'dandelion', 'daisy', 'daisy', 'sunflowers', 'roses', 'daisy', 'tulips', 'daisy', 'dandelion', 'sunflowers', 'roses', 'dandelion', 'tulips', 'tulips', 'sunflowers', 'sunflowers', 'tulips', 'sunflowers', 'sunflowers', 'roses', 'roses', 'daisy', 'roses', 'daisy', 'tulips', 'roses', 'sunflowers', 'sunflowers', 'daisy', 'sunflowers', 'roses', 'tulips', 'roses', 'roses', 'roses', 'dandelion', 'roses', 'roses', 'dandelion', 'sunflowers', 'daisy', 'daisy', 'tulips', 'daisy', 'dandelion', 'sunflowers', 'roses', 'sunflowers', 'roses', 'tulips', 'sunflowers', 'roses', 'sunflowers', 'tulips', 'sunflowers', 'sunflowers', 'sunflowers', 'daisy', 'roses', 'sunflowers', 'dandelion', 'dandelion', 'tulips', 'dandelion', 'sunflowers', 'dandelion', 'tulips', 'roses', 'dandelion', 'roses', 'daisy', 'tulips', 'daisy', 'roses', 'daisy', 'sunflowers', 'sunflowers', 'daisy', 'sunflowers', 'daisy', 'tulips', 'tulips', 'daisy', 'daisy', 'tulips', 'tulips', 'dandelion', 'dandelion', 'roses', 'roses', 'tulips', 'daisy', 'tulips', 'roses', 'tulips', 'roses', 'tulips', 'sunflowers', 'daisy', 'sunflowers', 'dandelion', 'dandelion', 'dandelion', 'roses', 'dandelion', 'dandelion', 'roses', 'daisy', 'daisy', 'dandelion', 'tulips', 'dandelion', 'dandelion', 'daisy', 'roses', 'dandelion', 'roses', 'sunflowers', 'roses', 'daisy', 'dandelion', 'dandelion', 'tulips', 'dandelion', 'tulips', 'dandelion', 'dandelion', 'sunflowers', 'sunflowers', 'daisy', 'dandelion', 'daisy', 'roses', 'roses']
# [val_loss, val_acc] [0.5346379280090332, 0.8125]
